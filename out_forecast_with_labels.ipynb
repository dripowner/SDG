# %%
import pandas as pd

# %%
df_pred = pd.read_csv("./result_data/clustering_results/cluster_labels.csv")
df_forecast = pd.read_csv("./result_data/forecast/forecats.csv")

# %%
df_pred
# Out:
#                                                    ЦУР     2016     2017  \
# 0                                                1.2.2    14.20    13.90
# 1                                                1.3.1  2241.00  2029.00
# 2                                                1.4.1    61.20    63.00
# 3                                                1.4.2  6227.10  6233.70
# 4                                   1.5.1 Пострадавшие   135.00   648.00
# ..                                                 ...      ...      ...
# 257                9.а.1 (Обязательства в млн дол США)    24.20   277.67
# 258                       9.а.2 (Изьято в млн дол США)   215.59   476.03
# 259                    9.а.3 (Поступило в млн дол США)   191.39   198.36
# 260  9.b.1 (Доля продукции высокотехнологичных и на...    19.00    20.30
# 261  Т 9.9 (Внутренние затраты на исследования и ра...     0.99     0.91
#
#         2018     2019     2020      2021      2022  AgglomerativeClustering  \
# ...

# %%
df_forecast["AgglomerativeClustering"] = df_pred["AgglomerativeClustering"]
df_forecast["KMeans"] = df_pred["KMeans"]

# %%
df_forecast.to_csv("./result_data/forecast/forecats_with_labels.csv")
